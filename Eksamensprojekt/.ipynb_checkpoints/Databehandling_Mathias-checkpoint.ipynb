# %% [markdown]
# # DATABEHANDLING

# %% [markdown]
# ### Starter med at indhente CSV-filer til DF's og lave disse til én stor

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os
import re
import itertools
import random
import threading
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import csv
import numpy as np
import re

# %%
pd.set_option('display.max_colwidth', None)
csv_files = ['rawdata/index_0_1000.csv', 
             'rawdata/index_1000_2000.csv', 'rawdata/index_2000_3000.csv', 'rawdata/index_3000_4000.csv',
             'rawdata/index_4000_5000.csv', 'rawdata/index_5000_6000.csv', 'rawdata/index_6000_7000.csv',
             'rawdata/index_7000_8000.csv', 'rawdata/index_8000_9000.csv', 'rawdata/index_9000_10000.csv',
            'rawdata/index_10000_11000.csv', 'rawdata/index_11000_12000.csv', 'rawdata/index_12000_13000.csv',
            'rawdata/index_13000_14000.csv', 'rawdata/index_14000_15000.csv', 'rawdata/index_15000_16000.csv',
            'rawdata/index_16000_17000.csv', 'rawdata/index_17000_18000.csv', 'rawdata/index_18000_19000.csv',
            'rawdata/index_19000_20000.csv']
dataframes = []

for file in csv_files:
    df = pd.read_csv(file)
    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=False)
combined_df.set_index('Unnamed: 0', inplace=True)
combined_df.index.name = None
combined_df
# Out:
#                                           Price  \
# Mellemtoftevej 36,2600            3.995.000 kr.
# Strandpromenaden 21, 1. tv.,3000  6.095.000 kr.
# Hjortdalvej 331,9460              3.995.000 kr.
# Lystgårdsparken 34,8300           2.798.000 kr.
# Fuglsøvej 92,8420                 6.000.000 kr.
# ...                                         ...
# Rishøjvej 17,8983                   895.000 kr.
# Vesterhavsgade 67, st. 3.,6700              NaN
# Selmers Vænge 4,2970                        NaN
# Munkebjergvej 84,2770                       NaN
# Brahesborgvej 30,7000                       NaN
#
#                                                                             Schoolname  \
# Mellemtoftevej 36,2600            Hospitalsskolen , Børne og Ungdomspsykiatrisk Center
# Strandpromenaden 21, 1. tv.,3000                                     Skolen i Bymidten
# Hjortdalvej 331,9460                                            Skovsgård Tranum skole
# Lystgårdsparken 34,8300                                               Parkvejens Skole
# Fuglsøvej 92,8420                                                           Molsskolen
# ...                                                                                ...
# Rishøjvej 17,8983                                                        Grønhøjskolen
# Vesterhavsgade 67, st. 3.,6700                                                     NaN
# Selmers Vænge 4,2970                                                               NaN
# Munkebjergvej 84,2770                                                              NaN
# Brahesborgvej 30,7000                                                              NaN
#
#                                  Distance to school School-grades  \
# Mellemtoftevej 36,2600                        391 m   Ikke oplyst
# Strandpromenaden 21, 1. tv.,3000              336 m   Ikke oplyst
# Hjortdalvej 331,9460                        5,24 km           6.9
# Lystgårdsparken 34,8300                     5,16 km             7
# Fuglsøvej 92,8420                           3,74 km           7.4
# ...                                             ...           ...
# Rishøjvej 17,8983                           4,94 km           6.2
# Vesterhavsgade 67, st. 3.,6700                  NaN           NaN
# Selmers Vænge 4,2970                            NaN           NaN
# Munkebjergvej 84,2770                           NaN           NaN
# Brahesborgvej 30,7000                           NaN           NaN
#
#                                       Trivsel      Boligtype  \
# Mellemtoftevej 36,2600            Ikke oplyst       Rækkehus
# Strandpromenaden 21, 1. tv.,3000  Ikke oplyst  Ejerlejlighed
# Hjortdalvej 331,9460                      3.6    Landejendom
# Lystgårdsparken 34,8300                   3.7          Villa
# Fuglsøvej 92,8420                         3.7          Villa
# ...                                       ...            ...
# Rishøjvej 17,8983                         3.6          Villa
# Vesterhavsgade 67, st. 3.,6700            NaN            NaN
# Selmers Vænge 4,2970                      NaN            NaN
# Munkebjergvej 84,2770                     NaN            NaN
# Brahesborgvej 30,7000                     NaN            NaN
#
#                                  Energy-classification      Radon Kommuneskat  \
# Mellemtoftevej 36,2600                   Energimærke D        Høj       24,6%
# Strandpromenaden 21, 1. tv.,3000     Energimærke A2015        Lav      25,52%
# Hjortdalvej 331,9460                     Energimærke D  Meget lav       25,7%
# Lystgårdsparken 34,8300                  Energimærke B     Mellem       25,1%
# Fuglsøvej 92,8420                        Energimærke D        Høj       25,9%
# ...                                                ...        ...         ...
# Rishøjvej 17,8983                        Energimærke F        Høj       25,8%
# Vesterhavsgade 67, st. 3.,6700                     NaN        NaN         NaN
# Selmers Vænge 4,2970                               NaN        NaN         NaN
# Munkebjergvej 84,2770                              NaN        NaN         NaN
# Brahesborgvej 30,7000                              NaN        NaN         NaN
#
#                                  Grundskyldspromillen  ...  \
# Mellemtoftevej 36,2600                           25‰.  ...
# Strandpromenaden 21, 1. tv.,3000               28,5‰.  ...
# Hjortdalvej 331,9460                          32,85‰.  ...
# Lystgårdsparken 34,8300                       30,32‰.  ...
# Fuglsøvej 92,8420                              33,8‰.  ...
# ...                                               ...  ...
# Rishøjvej 17,8983                             27,93‰.  ...
# Vesterhavsgade 67, st. 3.,6700                    NaN  ...
# Selmers Vænge 4,2970                              NaN  ...
# Munkebjergvej 84,2770                             NaN  ...
# Brahesborgvej 30,7000                             NaN  ...
#
#                                              Ejerudgift        Rooms  \
# Mellemtoftevej 36,2600            Ejerudg.: 2.889 kr/md   5 værelser
# Strandpromenaden 21, 1. tv.,3000  Ejerudg.: 6.056 kr/md   5 værelser
# Hjortdalvej 331,9460              Ejerudg.: 2.089 kr/md   5 værelser
# Lystgårdsparken 34,8300           Ejerudg.: 1.838 kr/md   4 værelser
# Fuglsøvej 92,8420                 Ejerudg.: 3.434 kr/md  12 værelser
# ...                                                 ...          ...
# Rishøjvej 17,8983                 Ejerudg.: 1.459 kr/md   5 værelser
# Vesterhavsgade 67, st. 3.,6700                     fejl         fejl
# Selmers Vænge 4,2970                               fejl         fejl
# Munkebjergvej 84,2770                              fejl         fejl
# Brahesborgvej 30,7000                              fejl         fejl
#
#                                         Build      Toilets Postal code  \
# Mellemtoftevej 36,2600            Opført 1947     1 toilet        2600
# Strandpromenaden 21, 1. tv.,3000  Opført 2020  2 toiletter        3000
# Hjortdalvej 331,9460              Opført 1912     1 toilet        9460
# Lystgårdsparken 34,8300           Opført 2008     1 toilet        8300
# Fuglsøvej 92,8420                 Opført 1884  4 toiletter        8420
# ...                                       ...          ...         ...
# Rishøjvej 17,8983                 Opført 1911     1 toilet        8983
# Vesterhavsgade 67, st. 3.,6700           fejl          NaN        fejl
# Selmers Vænge 4,2970                     fejl          NaN        fejl
# Munkebjergvej 84,2770                    fejl          NaN        fejl
# Brahesborgvej 30,7000                    fejl          NaN        fejl
#
#                                                                                                       link  \
# Mellemtoftevej 36,2600            https://www.boligsiden.dk/addresses/0a3f50a4-be85-32b8-e044-0003ba298018
# Strandpromenaden 21, 1. tv.,3000  https://www.boligsiden.dk/addresses/0d5cec39-0046-4f36-9850-8c2d08933fd5
# Hjortdalvej 331,9460              https://www.boligsiden.dk/addresses/39ff92cd-f2b1-0991-e044-0003ba298018
# Lystgårdsparken 34,8300           https://www.boligsiden.dk/addresses/363cc2db-6e07-1eb8-e044-0003ba298018
# Fuglsøvej 92,8420                 https://www.boligsiden.dk/addresses/0a3f50bf-6f17-32b8-e044-0003ba298018
# ...                                                                                                    ...
# Rishøjvej 17,8983                 https://www.boligsiden.dk/addresses/0a3f50c0-71a1-32b8-e044-0003ba298018
# Vesterhavsgade 67, st. 3.,6700    https://www.boligsiden.dk/addresses/0a3f50b9-5c39-32b8-e044-0003ba298018
# Selmers Vænge 4,2970              https://www.boligsiden.dk/addresses/0a3f50aa-1f5e-32b8-e044-0003ba298018
# Munkebjergvej 84,2770             https://www.boligsiden.dk/addresses/0a3f50a7-57be-32b8-e044-0003ba298018
# Brahesborgvej 30,7000             https://www.boligsiden.dk/addresses/0a3f50ba-87e6-32b8-e044-0003ba298018
#
#                                        Elevator       Altan        Terasse  \
# Mellemtoftevej 36,2600                      NaN         NaN            NaN
# Strandpromenaden 21, 1. tv.,3000  Elevator: Nej  Altan: Nej  Terrasse: Nej
# Hjortdalvej 331,9460                        NaN         NaN            NaN
# Lystgårdsparken 34,8300                     NaN         NaN            NaN
# Fuglsøvej 92,8420                           NaN         NaN            NaN
# ...                                         ...         ...            ...
# Rishøjvej 17,8983                           NaN         NaN            NaN
# Vesterhavsgade 67, st. 3.,6700             fejl        fejl           fejl
# Selmers Vænge 4,2970                       fejl        fejl           fejl
# Munkebjergvej 84,2770                      fejl        fejl           fejl
# Brahesborgvej 30,7000                      fejl        fejl           fejl
#
#                                  Toilet
# Mellemtoftevej 36,2600              NaN
# Strandpromenaden 21, 1. tv.,3000    NaN
# Hjortdalvej 331,9460                NaN
# Lystgårdsparken 34,8300             NaN
# Fuglsøvej 92,8420                   NaN
# ...                                 ...
# Rishøjvej 17,8983                   NaN
# Vesterhavsgade 67, st. 3.,6700     fejl
# Selmers Vænge 4,2970               fejl
# Munkebjergvej 84,2770              fejl
# Brahesborgvej 30,7000              fejl
#
# [19960 rows x 24 columns]

# %%
#Sorterer alt data med fejl i pris fra:
#Gemmer missing data i en dataframe
df_med_fejl=combined_df[pd.isna(combined_df['Price'])]
df_med_fejl


#Overskriver samlet dataframe, således at missing data (pga. fejl i kode) ikke optræder.
combined_df = combined_df.drop(df_med_fejl.index)
combined_df
# Out:
#                                            Price  \
# Mellemtoftevej 36,2600             3.995.000 kr.
# Strandpromenaden 21, 1. tv.,3000   6.095.000 kr.
# Hjortdalvej 331,9460               3.995.000 kr.
# Lystgårdsparken 34,8300            2.798.000 kr.
# Fuglsøvej 92,8420                  6.000.000 kr.
# ...                                          ...
# Trongårdsparken 91,2800           10.495.000 kr.
# Alpinavej 16,8660                  3.995.000 kr.
# Thorsvej 39,9700                   2.375.000 kr.
# Strandjægervej 21,3630             4.498.000 kr.
# Rishøjvej 17,8983                    895.000 kr.
#
#                                                                             Schoolname  \
# Mellemtoftevej 36,2600            Hospitalsskolen , Børne og Ungdomspsykiatrisk Center
# Strandpromenaden 21, 1. tv.,3000                                     Skolen i Bymidten
# Hjortdalvej 331,9460                                            Skovsgård Tranum skole
# Lystgårdsparken 34,8300                                               Parkvejens Skole
# Fuglsøvej 92,8420                                                           Molsskolen
# ...                                                                                ...
# Trongårdsparken 91,2800                                                Trongårdsskolen
# Alpinavej 16,8660                                                       Stilling Skole
# Thorsvej 39,9700                                                    Skoledistrikt Vest
# Strandjægervej 21,3630                                                Jægerspris Skole
# Rishøjvej 17,8983                                                        Grønhøjskolen
#
#                                  Distance to school School-grades  \
# Mellemtoftevej 36,2600                        391 m   Ikke oplyst
# Strandpromenaden 21, 1. tv.,3000              336 m   Ikke oplyst
# Hjortdalvej 331,9460                        5,24 km           6.9
# Lystgårdsparken 34,8300                     5,16 km             7
# Fuglsøvej 92,8420                           3,74 km           7.4
# ...                                             ...           ...
# Trongårdsparken 91,2800                       242 m             8
# Alpinavej 16,8660                             642 m           7.5
# Thorsvej 39,9700                              708 m   Ikke oplyst
# Strandjægervej 21,3630                     10,38 km           6.8
# Rishøjvej 17,8983                           4,94 km           6.2
#
#                                       Trivsel      Boligtype  \
# Mellemtoftevej 36,2600            Ikke oplyst       Rækkehus
# Strandpromenaden 21, 1. tv.,3000  Ikke oplyst  Ejerlejlighed
# Hjortdalvej 331,9460                      3.6    Landejendom
# Lystgårdsparken 34,8300                   3.7          Villa
# Fuglsøvej 92,8420                         3.7          Villa
# ...                                       ...            ...
# Trongårdsparken 91,2800                   3.8          Villa
# Alpinavej 16,8660                         3.7       Rækkehus
# Thorsvej 39,9700                  Ikke oplyst          Villa
# Strandjægervej 21,3630                    3.6          Villa
# Rishøjvej 17,8983                         3.6          Villa
#
#                                  Energy-classification      Radon Kommuneskat  \
# Mellemtoftevej 36,2600                   Energimærke D        Høj       24,6%
# Strandpromenaden 21, 1. tv.,3000     Energimærke A2015        Lav      25,52%
# Hjortdalvej 331,9460                     Energimærke D  Meget lav       25,7%
# Lystgårdsparken 34,8300                  Energimærke B     Mellem       25,1%
# Fuglsøvej 92,8420                        Energimærke D        Høj       25,9%
# ...                                                ...        ...         ...
# Trongårdsparken 91,2800                  Energimærke D        Lav      24,38%
# Alpinavej 16,8660                        Energimærke C     Mellem         26%
# Thorsvej 39,9700                         Energimærke D     Mellem       26,3%
# Strandjægervej 21,3630               Energimærke A2010     Mellem       25,8%
# Rishøjvej 17,8983                        Energimærke F        Høj       25,8%
#
#                                  Grundskyldspromillen  ...  \
# Mellemtoftevej 36,2600                           25‰.  ...
# Strandpromenaden 21, 1. tv.,3000               28,5‰.  ...
# Hjortdalvej 331,9460                          32,85‰.  ...
# Lystgårdsparken 34,8300                       30,32‰.  ...
# Fuglsøvej 92,8420                              33,8‰.  ...
# ...                                               ...  ...
# Trongårdsparken 91,2800                       21,49‰.  ...
# Alpinavej 16,8660                             24,66‰.  ...
# Thorsvej 39,9700                              31,23‰.  ...
# Strandjægervej 21,3630                         32,5‰.  ...
# Rishøjvej 17,8983                             27,93‰.  ...
#
#                                              Ejerudgift        Rooms  \
# Mellemtoftevej 36,2600            Ejerudg.: 2.889 kr/md   5 værelser
# Strandpromenaden 21, 1. tv.,3000  Ejerudg.: 6.056 kr/md   5 værelser
# Hjortdalvej 331,9460              Ejerudg.: 2.089 kr/md   5 værelser
# Lystgårdsparken 34,8300           Ejerudg.: 1.838 kr/md   4 værelser
# Fuglsøvej 92,8420                 Ejerudg.: 3.434 kr/md  12 værelser
# ...                                                 ...          ...
# Trongårdsparken 91,2800           Ejerudg.: 7.030 kr/md   6 værelser
# Alpinavej 16,8660                 Ejerudg.: 3.253 kr/md   4 værelser
# Thorsvej 39,9700                  Ejerudg.: 2.230 kr/md   7 værelser
# Strandjægervej 21,3630            Ejerudg.: 4.805 kr/md   8 værelser
# Rishøjvej 17,8983                 Ejerudg.: 1.459 kr/md   5 værelser
#
#                                         Build      Toilets Postal code  \
# Mellemtoftevej 36,2600            Opført 1947     1 toilet        2600
# Strandpromenaden 21, 1. tv.,3000  Opført 2020  2 toiletter        3000
# Hjortdalvej 331,9460              Opført 1912     1 toilet        9460
# Lystgårdsparken 34,8300           Opført 2008     1 toilet        8300
# Fuglsøvej 92,8420                 Opført 1884  4 toiletter        8420
# ...                                       ...          ...         ...
# Trongårdsparken 91,2800           Opført 1963  3 toiletter        2800
# Alpinavej 16,8660                 Opført 1978  2 toiletter        8660
# Thorsvej 39,9700                  Opført 1978  2 toiletter        9700
# Strandjægervej 21,3630            Opført 1787  2 toiletter        3630
# Rishøjvej 17,8983                 Opført 1911     1 toilet        8983
#
#                                                                                                       link  \
# Mellemtoftevej 36,2600            https://www.boligsiden.dk/addresses/0a3f50a4-be85-32b8-e044-0003ba298018
# Strandpromenaden 21, 1. tv.,3000  https://www.boligsiden.dk/addresses/0d5cec39-0046-4f36-9850-8c2d08933fd5
# Hjortdalvej 331,9460              https://www.boligsiden.dk/addresses/39ff92cd-f2b1-0991-e044-0003ba298018
# Lystgårdsparken 34,8300           https://www.boligsiden.dk/addresses/363cc2db-6e07-1eb8-e044-0003ba298018
# Fuglsøvej 92,8420                 https://www.boligsiden.dk/addresses/0a3f50bf-6f17-32b8-e044-0003ba298018
# ...                                                                                                    ...
# Trongårdsparken 91,2800           https://www.boligsiden.dk/addresses/0a3f50a6-6d9b-32b8-e044-0003ba298018
# Alpinavej 16,8660                 https://www.boligsiden.dk/addresses/0a3f50c2-206a-32b8-e044-0003ba298018
# Thorsvej 39,9700                  https://www.boligsiden.dk/addresses/0a3f50c6-fd6f-32b8-e044-0003ba298018
# Strandjægervej 21,3630            https://www.boligsiden.dk/addresses/0a3f50aa-47a5-32b8-e044-0003ba298018
# Rishøjvej 17,8983                 https://www.boligsiden.dk/addresses/0a3f50c0-71a1-32b8-e044-0003ba298018
#
#                                        Elevator       Altan        Terasse  \
# Mellemtoftevej 36,2600                      NaN         NaN            NaN
# Strandpromenaden 21, 1. tv.,3000  Elevator: Nej  Altan: Nej  Terrasse: Nej
# Hjortdalvej 331,9460                        NaN         NaN            NaN
# Lystgårdsparken 34,8300                     NaN         NaN            NaN
# Fuglsøvej 92,8420                           NaN         NaN            NaN
# ...                                         ...         ...            ...
# Trongårdsparken 91,2800                     NaN         NaN            NaN
# Alpinavej 16,8660                           NaN         NaN            NaN
# Thorsvej 39,9700                            NaN         NaN            NaN
# Strandjægervej 21,3630                      NaN         NaN            NaN
# Rishøjvej 17,8983                           NaN         NaN            NaN
#
#                                  Toilet
# Mellemtoftevej 36,2600              NaN
# Strandpromenaden 21, 1. tv.,3000    NaN
# Hjortdalvej 331,9460                NaN
# Lystgårdsparken 34,8300             NaN
# Fuglsøvej 92,8420                   NaN
# ...                                 ...
# Trongårdsparken 91,2800             NaN
# Alpinavej 16,8660                   NaN
# Thorsvej 39,9700                    NaN
# Strandjægervej 21,3630              NaN
# Rishøjvej 17,8983                   NaN
#
# [19867 rows x 24 columns]

# %%
def categorize_boligtype(x):
    if 'Landejendom' in x:
        return 'Landejendom'
    elif 'Villalejlighed' in x:
        return 'Villalejlighed'
    elif 'Villa' in x:
        return 'Villa'
    elif 'Ejerlejlighed' in x:
        return 'Ejerlejlighed'
    elif 'Rækkehus' in x:
        return 'Rækkehus'
    else:
        return x

combined_df['Boligtype'] = combined_df['Boligtype'].apply(categorize_boligtype)
combined_df['Boligtype'] = combined_df['Boligtype'].astype('category')

# %%
#Retrieving municipialities
"""print(combined_df['Kommune tekst'])"""
combined_df['Municipiality'] = combined_df['Kommune tekst'].apply(lambda x: re.findall(r'indbyggere i (.*?)\.', x)[0])
combined_df.drop('Kommune tekst', axis=1, inplace=True) #Removing the "kommune tekst" column. 
print(combined_df.columns)
combined_df['Municipiality'] = combined_df['Municipiality'].astype('category')
# Out:
# Index(['Price', 'Schoolname', 'Distance to school', 'School-grades', 'Trivsel',
#        'Boligtype', 'Energy-classification', 'Radon', 'Kommuneskat',
#        'Grundskyldspromillen', 'Liggetid', 'm2', 'Grund', 'Ejerudgift',
#        'Rooms', 'Build', 'Toilets', 'Postal code', 'link', 'Elevator', 'Altan',
#        'Terasse', 'Toilet', 'Municipiality'],
#       dtype='object')

# %%
#Kommuneskat
print(combined_df['Kommuneskat'].dtype)
combined_df['Kommuneskat'] = combined_df['Kommuneskat'].astype(str)
combined_df['Kommuneskat'] = combined_df['Kommuneskat'].str.replace(',', '.').str.replace('%', '') #komma til punktum og procenttegn væk
combined_df['Kommuneskat'] = combined_df['Kommuneskat'].astype(float)


print(combined_df['Ejerudgift'].dtype)
combined_df['Ejerudgift'] = combined_df['Ejerudgift'].astype(str)
combined_df['Ejerudgift'] = combined_df['Ejerudgift'].str.replace('Ejerudg.:', '').str.replace('kr/md', '') #komma til punktum og procenttegn væk
combined_df['Ejerudgift'] = combined_df['Ejerudgift'].astype(float)   #JEG HAR UDSKIFTET FEJL MED MISSING VALUES

print(combined_df['Grundskyldspromillen'].dtype)
combined_df['Grundskyldspromillen'] = combined_df['Grundskyldspromillen'].astype(str)
combined_df['Grundskyldspromillen'] = combined_df['Grundskyldspromillen'].str.replace(',', '.').str.replace('‰', '') #komma til punktum og procenttegn væk
combined_df['Grundskyldspromillen'] = combined_df['Grundskyldspromillen'].str.rstrip('.')
combined_df['Grundskyldspromillen'] = combined_df['Grundskyldspromillen'].astype(float)


print(combined_df['Liggetid'].dtype)
combined_df['Liggetid'] = combined_df['Liggetid'].astype(str)
combined_df['Liggetid'] = combined_df['Liggetid'].str.lstrip('Til salg i alt:').str.rstrip('e').str.rstrip('dag')
combined_df['Liggetid'] = combined_df['Liggetid'].astype(float)


print(combined_df['m2'].dtype)
combined_df['m2'] = combined_df['m2'].astype(str)
combined_df['m2'] = combined_df['m2'].str.rstrip('m²')
combined_df = combined_df.drop(combined_df[combined_df['m2'] == '- '].index)
combined_df['m2'] = combined_df['m2'].astype(float)

#OBS VED MANGLENDE GRUNDSTØRRELSE HAR JEG INDSAT LEJLIGHEDENS AREAL FRA M2
print(combined_df['Grund'].dtype)
combined_df['Grund'] = combined_df['Grund'].astype(str)
combined_df['Grund'] = combined_df['Grund'].str.extract(r'(\d+)').astype(float)
combined_df['Grund'] = combined_df['Grund'].fillna(combined_df['m2'])


print(combined_df['Rooms'].dtype)
combined_df['Rooms'] = combined_df['Rooms'].astype('str')
combined_df['Rooms'] = combined_df['Rooms'].apply(lambda x: int(re.findall(r'\d+', x)[0]) if re.findall(r'\d+', x) else np.nan)
#Dealing with missing Rooms: (Taking the mean of each "boligtype" and apply that)
mean_Rooms_by_type = combined_df.groupby('Boligtype')['Rooms'].mean()
combined_df['Rooms_imputed'] = combined_df['Rooms'].isna().astype(int) 

def fill_na_Rooms(row):
    if pd.isna(row['Rooms']):
        return mean_Rooms_by_type[row['Boligtype']]
    else:
        return row['Rooms']
# Apply the function to fill NaN values
combined_df['Rooms'] = combined_df.apply(fill_na_Rooms, axis=1)
# Out:
# object
# object
# object
# object
# object
# object
# object
# C:\Users\matli\AppData\Local\Temp\ipykernel_32080\63069814.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_Rooms_by_type = combined_df.groupby('Boligtype')['Rooms'].mean()

# %%
#### Price clearning ####

def clean_price(price):
    # Remove the currency symbol and dots, then convert to float
    return float(price.replace(' kr.', '').replace('.', ''))

# Apply the function to the Price column
combined_df.loc[:, 'Price'] = combined_df['Price'].apply(clean_price)


#### Distance to school cleaning ####
def convert_distance(distance):
    if 'km' in distance:
        # Replace comma with a dot and remove the 'km' text
        return float(distance.replace(' km', '').replace(',', '.'))
    elif 'm' in distance:
        # Extract the number, convert to float and divide by 1000 to convert to kilometers
        return float(distance.replace(' m', '').replace(',', '.')) / 1000
    return None

# Apply the function to the 'Distance to school' column
combined_df.loc[:, 'Distance to school'] = combined_df['Distance to school'].apply(convert_distance)


#### Trivsel cleaning ####
combined_df['Trivsel'] = combined_df['Trivsel'].replace(['Ikke oplyst'], pd.NA)

# Convert the 'Trivsel' column to float, handling NaN values appropriately
combined_df['Trivsel'] = pd.to_numeric(combined_df['Trivsel'], errors='coerce')


#### GRADES cleaning ####
combined_df['School-grades'] = combined_df['School-grades'].replace(['Ikke oplyst'], pd.NA)

# Convert the 'Trivsel' column to float, handling NaN values appropriately
combined_df['School-grades'] = pd.to_numeric(combined_df['School-grades'], errors='coerce')


"""
# Step 1: Calculate the mean 'Trivsel' for each Kommune
trivsel_sort_by='Municipiality'                               #OBS VÆLG KOMMUNE ISTEDET FOR BOLIG TYPE!!!!!!!!!!!!

trivsel_mean_by = combined_df.groupby(trivsel_sort_by)['Trivsel'].mean()
def fill_na_trivsel(row):
    if pd.isna(row['Trivsel']):
        return trivsel_mean_by[row[trivsel_sort_by]]
    else: 
        return row['Trivsel']
# Step 2: Create a dummy column indicating missing 'Trivsel' values (before imputation)
combined_df['Trivsel_imputed'] = combined_df['Trivsel'].isna().astype(int)

# Step 3: Fill missing 'Trivsel' values with the mean for each kommune
combined_df['Trivsel'] = combined_df.apply(fill_na_trivsel, axis=1)

#### GRADES cleaning ####
combined_df['School-grades'] = combined_df['School-grades'].replace(['Ikke oplyst'], pd.NA)

# Convert the 'Trivsel' column to float, handling NaN values appropriately
combined_df['School-grades'] = pd.to_numeric(combined_df['School-grades'], errors='coerce')

# Step 1: Calculate the mean 'Trivsel' for each Kommune
School_grades_sort_by='Municipiality'                               #OBS VÆLG KOMMUNE ISTEDET FOR BOLIGTYPE!!!!!!!!!!!!


School_grades_mean_by = combined_df.groupby(School_grades_sort_by)['School-grades'].mean()


def fill_na_grades(row):
    if pd.isna(row['School-grades']):
        return School_grades_mean_by[row[School_grades_sort_by]]
    else: 
        return row['School-grades']


# Step 2: Create a dummy column indicating missing 'grades' values (before imputation)
combined_df['Grades_imputed'] = combined_df['School-grades'].isna().astype(int)

# Step 3: Fill missing 'grades' values with the mean for each kommune
combined_df['School-grades'] = combined_df.apply(fill_na_grades, axis=1)
"""

#Price
combined_df['Price'] = combined_df['Price'].astype('float')
#Distance to school
combined_df['Distance to school'] = combined_df['Distance to school'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 8
#       5     return float(price.replace(' kr.', '').replace('.', ''))
#       7 # Apply the function to the Price column
# ----> 8 combined_df.loc[:, 'Price'] = combined_df['Price'].apply(clean_price)
#      11 #### Distance to school cleaning ####
#      12 def convert_distance(distance):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[34], line 5, in clean_price(price)
#       3 def clean_price(price):
#       4     # Remove the currency symbol and dots, then convert to float
# ----> 5     return float(price.replace(' kr.', '').replace('.', ''))
#
# AttributeError: 'float' object has no attribute 'replace'

# %% [markdown]
# ### Her starter databehandlingen

# %%
####BUILD
#combined_df = combined_df.replace('fejl', np.NaN)
combined_df['Build'] = combined_df['Build'].astype('str')
# Extract numbers from the 'Build' column using regex
combined_df['Build'] = combined_df['Build'].apply(lambda x: re.findall(r'\d+', x)[0] if re.findall(r'\d+', x) else np.nan)
# Making it intergers:
combined_df['Build'] = combined_df['Build'].astype('int')

###Toilets
combined_df['Toilets'] = combined_df['Toilets'].astype('str')
# Extract numbers from the 'Toilets' column using regex.. Setting missing values to NaN
combined_df['Toilets'] = combined_df['Toilets'].apply(lambda x: int(re.findall(r'\d+', x)[0]) if re.findall(r'\d+', x) else np.nan)
#Dealing with missing toilets: (Taking the mean of each "boligtype" and apply that)
mean_toilets_by_type = combined_df.groupby('Boligtype')['Toilets'].mean()
combined_df['Toilets_imputed'] = combined_df['Toilets'].isna().astype(int) 

def fill_na_toilets(row):
    if pd.isna(row['Toilets']):
        return mean_toilets_by_type[row['Boligtype']]
    else:
        return row['Toilets']
# Apply the function to fill NaN values
combined_df['Toilets'] = combined_df.apply(fill_na_toilets, axis=1)

###Elevator -> Setting values to 0 if either NaN or Elevator: Nej
combined_df['Elevator'] = combined_df['Elevator'].astype('str')
combined_df['Elevator'] = combined_df['Elevator'].apply(lambda x: 1 if re.findall(r'\bJa\b', x) else 0)

###Altan
combined_df['Altan'] = combined_df['Altan'].astype('str')
combined_df['Altan'] = combined_df['Altan'].apply(lambda x: 1 if re.findall(r'\bJa\b', x) else 0)

###Terasse
combined_df['Terasse'] = combined_df['Terasse'].astype('str')
combined_df['Terasse'] = combined_df['Terasse'].apply(lambda x: 1 if re.findall(r'\bJa\b', x) else 0)

###Dropping Toilet-column
combined_df.drop('Toilet', axis=1, inplace=True)

###Postial code
combined_df['Postal code'] = combined_df['Postal code'].astype('category')

###Energy-classification
combined_df['Energy-classification'] = combined_df['Energy-classification'].astype('str')
combined_df['Energy-classification'] = combined_df['Energy-classification'].str.lstrip('Energimærke')
combined_df['Energy-classification'] = combined_df['Energy-classification'].astype('category')

###Radon
combined_df['Radon'] = combined_df['Radon'].astype('category')
# Out:
# C:\Users\matli\AppData\Local\Temp\ipykernel_32080\4196732420.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_toilets_by_type = combined_df.groupby('Boligtype')['Toilets'].mean()

# %%
combined_df
combined_df[pd.isna(combined_df['Toilets'])]
combined_df[combined_df['Elevator'] == 1]

#combined_df['Boligtype'].astype('str').unique()
combined_df
combined_df[combined_df['Toilets_imputed'] == 1]
combined_df
combined_df['Boligtype'].astype('str').unique()
combined_df[combined_df['Boligtype'] == 'Villalejlighed']
# Out:
#                                     Price             Schoolname  \
# Dirchsvej 34, 1.,2300           5195000.0         Gerbrandskolen
# Torvet 2F, 2. th.,9492          3425000.0   Skolecenter Jetsmark
# Langesvej 35, 1.,3400           4250000.0  Frederiksborg Byskole
# Grubbemøllevej 26, 1.,5700      1075000.0           Vestre Skole
# Øverødvej 66B, 1.,2840          9500000.0           Skovlyskolen
# ...                                   ...                    ...
# Hans Jensens Vej 21, 1.,2900    8995000.0       Dyssegårdsskolen
# Frodesgade 26, st.,6700         1798000.0    Danmarksgades Skole
# H A Clausens Vej 26, st.,2820  11250000.0         Gentofte Skole
# Annebergvej 29, st.,9000        3195000.0     Vesterkærets Skole
# Studsgaardsgade 34, st.,2100    4995000.0     Nørre Fælled Skole
#
#                                Distance to school  School-grades  Trivsel  \
# Dirchsvej 34, 1.,2300                       0.660            6.7      3.8
# Torvet 2F, 2. th.,9492                      7.160            6.6      3.7
# Langesvej 35, 1.,3400                       0.459            7.9      3.7
# Grubbemøllevej 26, 1.,5700                  1.240            5.9      3.7
# Øverødvej 66B, 1.,2840                      0.944            8.5      3.8
# ...                                           ...            ...      ...
# Hans Jensens Vej 21, 1.,2900                0.748            8.4      3.8
# Frodesgade 26, st.,6700                     0.541            NaN      NaN
# H A Clausens Vej 26, st.,2820               0.742            8.4      3.8
# Annebergvej 29, st.,9000                    0.918            7.0      3.7
# Studsgaardsgade 34, st.,2100                0.506            6.9      3.8
#
#                                     Boligtype Energy-classification  \
# Dirchsvej 34, 1.,2300          Villalejlighed                     D
# Torvet 2F, 2. th.,9492         Villalejlighed                 A2015
# Langesvej 35, 1.,3400          Villalejlighed                     D
# Grubbemøllevej 26, 1.,5700     Villalejlighed                     D
# Øverødvej 66B, 1.,2840         Villalejlighed                     C
# ...                                       ...                   ...
# Hans Jensens Vej 21, 1.,2900   Villalejlighed                     C
# Frodesgade 26, st.,6700        Villalejlighed                     D
# H A Clausens Vej 26, st.,2820  Villalejlighed                     E
# Annebergvej 29, st.,9000       Villalejlighed                     E
# Studsgaardsgade 34, st.,2100   Villalejlighed                     C
#
#                                    Radon  Kommuneskat  Grundskyldspromillen  \
# Dirchsvej 34, 1.,2300             Mellem        23.70                 34.00
# Torvet 2F, 2. th.,9492            Mellem        25.70                 32.85
# Langesvej 35, 1.,3400             Mellem        25.60                 20.65
# Grubbemøllevej 26, 1.,5700     Meget høj        26.30                 23.32
# Øverødvej 66B, 1.,2840            Mellem        23.21                 22.93
# ...                                  ...          ...                   ...
# Hans Jensens Vej 21, 1.,2900      Mellem        24.17                 16.00
# Frodesgade 26, st.,6700        Meget lav        25.80                 25.29
# H A Clausens Vej 26, st.,2820     Mellem        24.17                 16.00
# Annebergvej 29, st.,9000             Lav        25.40                 26.95
# Studsgaardsgade 34, st.,2100      Mellem        23.70                 34.00
#
#                                ...  Postal code  \
# Dirchsvej 34, 1.,2300          ...         2300
# Torvet 2F, 2. th.,9492         ...         9492
# Langesvej 35, 1.,3400          ...         3400
# Grubbemøllevej 26, 1.,5700     ...         5700
# Øverødvej 66B, 1.,2840         ...         2840
# ...                            ...          ...
# Hans Jensens Vej 21, 1.,2900   ...         2900
# Frodesgade 26, st.,6700        ...         6700
# H A Clausens Vej 26, st.,2820  ...         2820
# Annebergvej 29, st.,9000       ...         9000
# Studsgaardsgade 34, st.,2100   ...         2100
#
#                                                                                                    link  \
# Dirchsvej 34, 1.,2300          https://www.boligsiden.dk/addresses/0a3f509d-c94a-32b8-e044-0003ba298018
# Torvet 2F, 2. th.,9492         https://www.boligsiden.dk/addresses/4e09420a-4704-4853-972a-1153b7060eaf
# Langesvej 35, 1.,3400          https://www.boligsiden.dk/addresses/0a3f50a9-c222-32b8-e044-0003ba298018
# Grubbemøllevej 26, 1.,5700     https://www.boligsiden.dk/addresses/0a3f50b5-7731-32b8-e044-0003ba298018
# Øverødvej 66B, 1.,2840         https://www.boligsiden.dk/addresses/0a3f50a7-0397-32b8-e044-0003ba298018
# ...                                                                                                 ...
# Hans Jensens Vej 21, 1.,2900   https://www.boligsiden.dk/addresses/0a3f50a3-c51e-32b8-e044-0003ba298018
# Frodesgade 26, st.,6700        https://www.boligsiden.dk/addresses/0a3f50b8-dbf5-32b8-e044-0003ba298018
# H A Clausens Vej 26, st.,2820  https://www.boligsiden.dk/addresses/0a3f50a3-c471-32b8-e044-0003ba298018
# Annebergvej 29, st.,9000       https://www.boligsiden.dk/addresses/0a3f50c9-b601-32b8-e044-0003ba298018
# Studsgaardsgade 34, st.,2100   https://www.boligsiden.dk/addresses/0a3f50a0-f134-32b8-e044-0003ba298018
#
#                                Elevator  Altan  Terasse       Municipiality  \
# Dirchsvej 34, 1.,2300                 0      0        0  Københavns Kommune
# Torvet 2F, 2. th.,9492                1      1        0  Jammerbugt Kommune
# Langesvej 35, 1.,3400                 0      1        0    Hillerød Kommune
# Grubbemøllevej 26, 1.,5700            0      0        0   Svendborg Kommune
# Øverødvej 66B, 1.,2840                0      0        0   Rudersdal Kommune
# ...                                 ...    ...      ...                 ...
# Hans Jensens Vej 21, 1.,2900          0      0        0    Gentofte Kommune
# Frodesgade 26, st.,6700               0      0        0     Esbjerg Kommune
# H A Clausens Vej 26, st.,2820         0      0        0    Gentofte Kommune
# Annebergvej 29, st.,9000              0      0        0     Aalborg Kommune
# Studsgaardsgade 34, st.,2100          0      0        0  Københavns Kommune
#
#                                Rooms_imputed Trivsel_imputed Grades_imputed  \
# Dirchsvej 34, 1.,2300                      0               0              0
# Torvet 2F, 2. th.,9492                     0               0              0
# Langesvej 35, 1.,3400                      0               0              0
# Grubbemøllevej 26, 1.,5700                 0               0              0
# Øverødvej 66B, 1.,2840                     0               0              0
# ...                                      ...             ...            ...
# Hans Jensens Vej 21, 1.,2900               0               0              0
# Frodesgade 26, st.,6700                    0               1              1
# H A Clausens Vej 26, st.,2820              0               0              0
# Annebergvej 29, st.,9000                   0               0              0
# Studsgaardsgade 34, st.,2100               0               0              0
#
#                                Toilets_imputed
# Dirchsvej 34, 1.,2300                        0
# Torvet 2F, 2. th.,9492                       0
# Langesvej 35, 1.,3400                        0
# Grubbemøllevej 26, 1.,5700                   0
# Øverødvej 66B, 1.,2840                       0
# ...                                        ...
# Hans Jensens Vej 21, 1.,2900                 0
# Frodesgade 26, st.,6700                      0
# H A Clausens Vej 26, st.,2820                0
# Annebergvej 29, st.,9000                     0
# Studsgaardsgade 34, st.,2100                 0
#
# [99 rows x 27 columns]

# %%
combined_df['Boligtype'].astype('str').unique()
# Out:
# array(['Rækkehus', 'Ejerlejlighed', 'Landejendom', 'Villa',
#        'Villalejlighed', 'Fritidsbolig'], dtype=object)

# %%
#Duplicates
combined_df = combined_df.drop_duplicates()
combined_df
# Out:
#                                        Price  \
# Mellemtoftevej 36,2600             3995000.0
# Strandpromenaden 21, 1. tv.,3000   6095000.0
# Hjortdalvej 331,9460               3995000.0
# Lystgårdsparken 34,8300            2798000.0
# Fuglsøvej 92,8420                  6000000.0
# ...                                      ...
# Trongårdsparken 91,2800           10495000.0
# Alpinavej 16,8660                  3995000.0
# Thorsvej 39,9700                   2375000.0
# Strandjægervej 21,3630             4498000.0
# Rishøjvej 17,8983                   895000.0
#
#                                                                             Schoolname  \
# Mellemtoftevej 36,2600            Hospitalsskolen , Børne og Ungdomspsykiatrisk Center
# Strandpromenaden 21, 1. tv.,3000                                     Skolen i Bymidten
# Hjortdalvej 331,9460                                            Skovsgård Tranum skole
# Lystgårdsparken 34,8300                                               Parkvejens Skole
# Fuglsøvej 92,8420                                                           Molsskolen
# ...                                                                                ...
# Trongårdsparken 91,2800                                                Trongårdsskolen
# Alpinavej 16,8660                                                       Stilling Skole
# Thorsvej 39,9700                                                    Skoledistrikt Vest
# Strandjægervej 21,3630                                                Jægerspris Skole
# Rishøjvej 17,8983                                                        Grønhøjskolen
#
#                                   Distance to school  School-grades  Trivsel  \
# Mellemtoftevej 36,2600                         0.391            NaN      NaN
# Strandpromenaden 21, 1. tv.,3000               0.336            NaN      NaN
# Hjortdalvej 331,9460                           5.240            6.9      3.6
# Lystgårdsparken 34,8300                        5.160            7.0      3.7
# Fuglsøvej 92,8420                              3.740            7.4      3.7
# ...                                              ...            ...      ...
# Trongårdsparken 91,2800                        0.242            8.0      3.8
# Alpinavej 16,8660                              0.642            7.5      3.7
# Thorsvej 39,9700                               0.708            NaN      NaN
# Strandjægervej 21,3630                        10.380            6.8      3.6
# Rishøjvej 17,8983                              4.940            6.2      3.6
#
#                                       Boligtype Energy-classification  \
# Mellemtoftevej 36,2600                 Rækkehus                     D
# Strandpromenaden 21, 1. tv.,3000  Ejerlejlighed                 A2015
# Hjortdalvej 331,9460                Landejendom                     D
# Lystgårdsparken 34,8300                   Villa                     B
# Fuglsøvej 92,8420                         Villa                     D
# ...                                         ...                   ...
# Trongårdsparken 91,2800                   Villa                     D
# Alpinavej 16,8660                      Rækkehus                     C
# Thorsvej 39,9700                          Villa                     D
# Strandjægervej 21,3630                    Villa                 A2010
# Rishøjvej 17,8983                         Villa                     F
#
#                                       Radon  Kommuneskat  \
# Mellemtoftevej 36,2600                  Høj        24.60
# Strandpromenaden 21, 1. tv.,3000        Lav        25.52
# Hjortdalvej 331,9460              Meget lav        25.70
# Lystgårdsparken 34,8300              Mellem        25.10
# Fuglsøvej 92,8420                       Høj        25.90
# ...                                     ...          ...
# Trongårdsparken 91,2800                 Lav        24.38
# Alpinavej 16,8660                    Mellem        26.00
# Thorsvej 39,9700                     Mellem        26.30
# Strandjægervej 21,3630               Mellem        25.80
# Rishøjvej 17,8983                       Høj        25.80
#
#                                   Grundskyldspromillen  ...  Build  Toilets  \
# Mellemtoftevej 36,2600                           25.00  ...   1947      1.0
# Strandpromenaden 21, 1. tv.,3000                 28.50  ...   2020      2.0
# Hjortdalvej 331,9460                             32.85  ...   1912      1.0
# Lystgårdsparken 34,8300                          30.32  ...   2008      1.0
# Fuglsøvej 92,8420                                33.80  ...   1884      4.0
# ...                                                ...  ...    ...      ...
# Trongårdsparken 91,2800                          21.49  ...   1963      3.0
# Alpinavej 16,8660                                24.66  ...   1978      2.0
# Thorsvej 39,9700                                 31.23  ...   1978      2.0
# Strandjægervej 21,3630                           32.50  ...   1787      2.0
# Rishøjvej 17,8983                                27.93  ...   1911      1.0
#
#                                   Postal code  \
# Mellemtoftevej 36,2600                   2600
# Strandpromenaden 21, 1. tv.,3000         3000
# Hjortdalvej 331,9460                     9460
# Lystgårdsparken 34,8300                  8300
# Fuglsøvej 92,8420                        8420
# ...                                       ...
# Trongårdsparken 91,2800                  2800
# Alpinavej 16,8660                        8660
# Thorsvej 39,9700                         9700
# Strandjægervej 21,3630                   3630
# Rishøjvej 17,8983                        8983
#
#                                                                                                       link  \
# Mellemtoftevej 36,2600            https://www.boligsiden.dk/addresses/0a3f50a4-be85-32b8-e044-0003ba298018
# Strandpromenaden 21, 1. tv.,3000  https://www.boligsiden.dk/addresses/0d5cec39-0046-4f36-9850-8c2d08933fd5
# Hjortdalvej 331,9460              https://www.boligsiden.dk/addresses/39ff92cd-f2b1-0991-e044-0003ba298018
# Lystgårdsparken 34,8300           https://www.boligsiden.dk/addresses/363cc2db-6e07-1eb8-e044-0003ba298018
# Fuglsøvej 92,8420                 https://www.boligsiden.dk/addresses/0a3f50bf-6f17-32b8-e044-0003ba298018
# ...                                                                                                    ...
# Trongårdsparken 91,2800           https://www.boligsiden.dk/addresses/0a3f50a6-6d9b-32b8-e044-0003ba298018
# Alpinavej 16,8660                 https://www.boligsiden.dk/addresses/0a3f50c2-206a-32b8-e044-0003ba298018
# Thorsvej 39,9700                  https://www.boligsiden.dk/addresses/0a3f50c6-fd6f-32b8-e044-0003ba298018
# Strandjægervej 21,3630            https://www.boligsiden.dk/addresses/0a3f50aa-47a5-32b8-e044-0003ba298018
# Rishøjvej 17,8983                 https://www.boligsiden.dk/addresses/0a3f50c0-71a1-32b8-e044-0003ba298018
#
#                                   Elevator  Altan  Terasse  \
# Mellemtoftevej 36,2600                   0      0        0
# Strandpromenaden 21, 1. tv.,3000         0      0        0
# Hjortdalvej 331,9460                     0      0        0
# Lystgårdsparken 34,8300                  0      0        0
# Fuglsøvej 92,8420                        0      0        0
# ...                                    ...    ...      ...
# Trongårdsparken 91,2800                  0      0        0
# Alpinavej 16,8660                        0      0        0
# Thorsvej 39,9700                         0      0        0
# Strandjægervej 21,3630                   0      0        0
# Rishøjvej 17,8983                        0      0        0
#
#                                            Municipiality Rooms_imputed  \
# Mellemtoftevej 36,2600                  Glostrup Kommune             0
# Strandpromenaden 21, 1. tv.,3000       Helsingør Kommune             0
# Hjortdalvej 331,9460                  Jammerbugt Kommune             0
# Lystgårdsparken 34,8300                    Odder Kommune             0
# Fuglsøvej 92,8420                       Syddjurs Kommune             0
# ...                                                  ...           ...
# Trongårdsparken 91,2800           Lyngby-Taarbæk Kommune             0
# Alpinavej 16,8660                    Skanderborg Kommune             0
# Thorsvej 39,9700                     Brønderslev Kommune             0
# Strandjægervej 21,3630             Frederikssund Kommune             0
# Rishøjvej 17,8983                        Randers Kommune             0
#
#                                   Toilets_imputed
# Mellemtoftevej 36,2600                          0
# Strandpromenaden 21, 1. tv.,3000                0
# Hjortdalvej 331,9460                            0
# Lystgårdsparken 34,8300                         0
# Fuglsøvej 92,8420                               0
# ...                                           ...
# Trongårdsparken 91,2800                         0
# Alpinavej 16,8660                               0
# Thorsvej 39,9700                                0
# Strandjægervej 21,3630                          0
# Rishøjvej 17,8983                               0
#
# [19851 rows x 25 columns]

# %%
combined_df.to_csv(f'outputdata/df_final.csv', index=True)
