# %% [markdown]
# # Descriptive analysis

# %% [markdown]
# This notebook is used primarily to calculate descriptive statistics for the dataset providing information on houses for sale in Denmark.

# %%
#Importing libaries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %%
#Importing dataset
pd.set_option('display.max_rows', None)
csv_file_path = '../outputdata/df_final.csv'
df_final = pd.read_csv(csv_file_path)
df_final.set_index('Unnamed: 0', inplace=True)
df_final.index.name = None

# %%
df_plotting = df_final
df_plotting['pris/m2'] = df_plotting['Price']/df_plotting['m2']

# %% [markdown]
# # DATA-PROCESSING

# %%
print(df_final.groupby('Municipiality')['pris/m2'].max().idxmax())
print(df_final.groupby('Municipiality')['pris/m2'].max().max())
print(df_final.loc[df_final['pris/m2'].idxmax()]) #Det viser sig at der er en landejendom.
# Out:
# Herning Kommune
# 825000.0
# Price                                                            1650000.0
# Schoolname                                                 Vildbjerg Skole
# Distance to school                                                    3.98
# School-grades                                                          7.2
# Trivsel                                                                3.7
# Boligtype                                                      Landejendom
# Energy-classification                                                    F
# Radon                                                                  Lav
# Kommuneskat                                                           24.9
# Grundskyldspromillen                                                 20.53
# Liggetid                                                              68.0
# m2                                                                     2.0
# Grund                                                             148153.0
# Ejerudgift                                                           888.0
# Rooms                                                                  1.0
# Build                                                                 1900
# Toilets                                                           1.728638
# Postal code                                                           7480
# link                     https://www.boligsiden.dk/addresses/7e50721c-6...
# Elevator                                                                 0
# Altan                                                                    0
# Terasse                                                                  0
# Municipiality                                              Herning Kommune
# Rooms_imputed                                                            0
# Toilets_imputed                                                          1
# pris/m2                                                           825000.0
# Name: Smækbjergvej 18C,7480, dtype: object

# %%
#Counting houses for sale in each Municipiality
print(df_final.groupby('Muncipiality')['pris/m2'].count())
# Out:
# Muncipiality
# Aabenraa Kommune              76
# Aalborg Kommune              385
# Aarhus Kommune               607
# Albertslund Kommune           12
# Allerød Kommune               38
# Assens Kommune                86
# Ballerup Kommune              37
# Billund Kommune               41
# Bornholm Kommune              92
# Brøndby Kommune               30
# Brønderslev Kommune           87
# Dragør Kommune                28
# Egedal Kommune                83
# Esbjerg Kommune              187
# Faaborg-Midtfyn Kommune      104
# Fanø Kommune                  10
# Favrskov Kommune              92
# Faxe Kommune                  84
# Fredensborg Kommune           90
# Fredericia Kommune            80
# Frederiksberg Kommune        101
# Frederikshavn Kommune        140
# Frederikssund Kommune         81
# Furesø Kommune                56
# Gentofte Kommune             127
# Gladsaxe Kommune              87
# Glostrup Kommune              23
# Greve Kommune                 84
# Gribskov Kommune             105
# Guldborgsund Kommune         114
# Haderslev Kommune            104
# Halsnæs Kommune               42
# Hedensted Kommune             87
# Helsingør Kommune            136
# Herlev Kommune                25
# Herning Kommune              140
# Hillerød Kommune              85
# Hjørring Kommune             165
# Holbæk Kommune               131
# Holstebro Kommune             92
# Horsens Kommune              191
# Hvidovre Kommune              51
# Høje-Taastrup Kommune        101
# Hørsholm Kommune              74
# Ikast-Brande Kommune          68
# Ishøj Kommune                 24
# Jammerbugt Kommune            91
# Kalundborg Kommune            99
# Kerteminde Kommune            38
# Kolding Kommune              176
# Københavns Kommune           658
# Køge Kommune                 121
# Langeland Kommune             24
# Lejre Kommune                 59
# Lemvig Kommune                31
# Lolland Kommune               84
# Lyngby-Taarbæk Kommune        81
# Læsø Kommune                   4
# Mariagerfjord Kommune         94
# Middelfart Kommune            76
# Morsø Kommune                 33
# Norddjurs Kommune             58
# Nordfyns Kommune              56
# Nyborg Kommune                67
# Næstved Kommune              142
# Odder Kommune                 48
# Odense Kommune               279
# Odsherred Kommune             81
# Randers Kommune              220
# Rebild Kommune                75
# Ringkøbing-Skjern Kommune     91
# Ringsted Kommune              55
# Roskilde Kommune             113
# Rudersdal Kommune            118
# Rødovre Kommune               57
# Samsø Kommune                 19
# Silkeborg Kommune            183
# Skanderborg Kommune          128
# Skive Kommune                 92
# Slagelse Kommune             134
# Solrød Kommune                43
# Sorø Kommune                  69
# Stevns Kommune                47
# Struer Kommune                45
# Svendborg Kommune            138
# Syddjurs Kommune              91
# Sønderborg Kommune           103
# Thisted Kommune               87
# Tårnby Kommune                61
# Tønder Kommune                64
# Vallensbæk Kommune            31
# Varde Kommune                 99
# Vejen Kommune                 73
# Vejle Kommune                192
# Vesthimmerlands Kommune       86
# Viborg Kommune               190
# Vordingborg Kommune          109
# Ærø Kommune                   20
# Name: pris/m2, dtype: int64

# %%
#Exploratory plotting
# Creating subplots without shared x-axis
#df_plotting['Price'] = df_plotting['Price'].clip(upper=15000000)
#df_plotting['m2'] = df_plotting['m2'].clip(upper=600)
#df_plotting['pris/m2'] = df_plotting['pris/m2'].clip(upper=100000)


# Define a formatter function to convert values to millions
def millions(x, pos):
    return f'{int(x / 1_000_000)}M'

# Apply the formatter to the axis
formatter = FuncFormatter(millions)


f, ax = plt.subplots(1, 2, figsize=(10, 4))

# Plotting the distributions
sns.distplot(df_plotting['Price'], ax=ax[0], kde=True)
sns.distplot(df_plotting['m2'], ax=ax[1])

# Formatting the x-axes (if needed)
ax[0].xaxis.set_major_formatter(formatter)
ax[0].set_xlabel('Price')
ax[1].set_xlabel('Square Meters')

print(df_final['pris/m2'].median())

df_median_price = df_final.groupby('Municipiality')['pris/m2'].median()
df_median_price
print(df_median_price.min())
print(df_median_price.max())
print(df_median_price.idxmin())
print(df_median_price.idxmax())
# Out:
# C:\Users\matli\AppData\Local\Temp\ipykernel_33420\3350620834.py:19: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_plotting['Price'], ax=ax[0], kde=True)
# C:\Users\matli\AppData\Local\Temp\ipykernel_33420\3350620834.py:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_plotting['m2'], ax=ax[1])
# 18472.222222222223
# 5639.097744360903
# 67638.94541015057
# Lolland Kommune
# Gentofte Kommune
# Herning Kommune
# 825000.0
# Price                                                            1650000.0
# Schoolname                                                 Vildbjerg Skole
# Distance to school                                                    3.98
# School-grades                                                          7.2
# Trivsel                                                                3.7
# Boligtype                                                      Landejendom
# Energy-classification                                                    F
# Radon                                                                  Lav
# Kommuneskat                                                           24.9
# Grundskyldspromillen                                                 20.53
# Liggetid                                                              68.0
# m2                                                                     2.0
# Grund                                                             148153.0
# Ejerudgift                                                           888.0
# Rooms                                                                  1.0
# Build                                                                 1900
# Toilets                                                           1.728638
# Postal code                                                           7480
# link                     https://www.boligsiden.dk/addresses/7e50721c-6...
# Elevator                                                                 0
# Altan                                                                    0
# Terasse                                                                  0
# Municipiality                                              Herning Kommune
# Rooms_imputed                                                            0
# Toilets_imputed                                                          1
# pris/m2                                                           825000.0
# Name: Smækbjergvej 18C,7480, dtype: object

# %%
# Function to format the x-axis labels in thousands
def thousands_formatter(x, pos):
    return f'{int(x/1000)}K'

filter = ['Københavns Kommune', 'Gentofte Kommune', 'Herning Kommune', 'Lolland Kommune']
df_filtered = df_plotting[df_plotting['Municipiality'].isin(filter)]

f,ax = plt.subplots(1,2, sharex=False, figsize=(10,6))

sns.kdeplot(data=df_filtered, x='pris/m2', hue='Municipiality', fill=False, ax=ax[1])
sns.kdeplot(data=df_plotting, x='pris/m2', fill=False, label='Country dist', ax=ax[0])

#Formatting:
ax[0].set_xlabel('Price/m2')
ax[1].set_xlabel('Price/m2')
ax[0].set_ylabel('Density')
ax[0].xaxis.set_major_formatter(FuncFormatter(thousands_formatter))
ax[1].xaxis.set_major_formatter(FuncFormatter(thousands_formatter))


#f.suptitle('Density Plot of Price/m2 for selected Municipialities')
plt.savefig('price_m2_municipialities.png', dpi=300, bbox_inches='tight')
